# %% [markdown]
# # CONFIRMED CASES OF COVID19 IN THE WORLD (FROM 22/01/2020 UNTIL TODAY)
#
#
# + ## Dataset: Public data COVID 19: (https://github.com/CSSEGISandData/COVID-19/tree/master/csse_covid_19_data/csse_covid_19_time_series)
#
#
# + ### Data cleaning and data wrangling with python: pandas library (https://pandas.pydata.org/)
# + ### Data visualization with Flourish (https://flourish.studio/)

# %% [markdown]
# ### 1. READ CSV WITH PANDAS

# %%
import pandas as pd

path = r'C:\Users\adria\Desktop\Python\BAR CHART RACE\time_series_covid19_confirmed_global.csv' 
df = pd.read_csv(path)
df.head(10)
# Out:
#                  Province/State       Country/Region       Lat        Long  \
# 0                           NaN          Afghanistan  33.93911   67.709953
# 1                           NaN              Albania  41.15330   20.168300
# 2                           NaN              Algeria  28.03390    1.659600
# 3                           NaN              Andorra  42.50630    1.521800
# 4                           NaN               Angola -11.20270   17.873900
# 5                           NaN           Antarctica -71.94990   23.347000
# 6                           NaN  Antigua and Barbuda  17.06080  -61.796400
# 7                           NaN            Argentina -38.41610  -63.616700
# 8                           NaN              Armenia  40.06910   45.038200
# 9  Australian Capital Territory            Australia -35.47350  149.012400
#
#    1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...   2/2/22  \
# 0        0        0        0        0        0        0  ...   164190
# ...

# %% [markdown]
# ### 2. General stadistics

# %%
# Dataset - shape
print(f'We have {df.shape[0]} rows and {df.shape[1]} columns.')
# Out:
# We have 282 rows and 753 columns.

# %%
df.info() # dataset info # 756 columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 282 entries, 0 to 281
# Columns: 756 entries, Province/State to 2/11/22
# dtypes: float64(2), int64(752), object(2)
# memory usage: 1.6+ MB

# %%
df.describe() # dataset stadistics
# Out:
#               Lat        Long     1/22/20     1/23/20     1/24/20     1/25/20  \
# count  280.000000  280.000000  282.000000  282.000000  282.000000  282.000000
# mean    19.897621   22.132442    1.975177    2.322695    3.336879    5.085106
# std     25.814751   76.136857   26.495875   26.593261   33.108632   46.081390
# min    -71.949900 -178.116500    0.000000    0.000000    0.000000    0.000000
# 25%      4.562000  -27.932425    0.000000    0.000000    0.000000    0.000000
# 50%     21.517170   20.972650    0.000000    0.000000    0.000000    0.000000
# 75%     40.252717   85.953175    0.000000    0.000000    0.000000    0.000000
# max     71.706900  178.065000  444.000000  444.000000  549.000000  761.000000
#
#            1/26/20      1/27/20      1/28/20      1/29/20  ...        2/2/22  \
# count   282.000000   282.000000   282.000000   282.000000  ...  2.820000e+02
# mean      7.510638    10.379433    19.780142    21.868794  ...  1.366529e+06
# ...

# %% [markdown]
# ### 3. Data cleaning / data wrangling

# %%
# null values
df.isna().sum()
# Out:
# Province/State    195
# Country/Region      0
# Lat                 2
# Long                2
# 1/22/20             0
#                  ...
# 2/7/22              0
# 2/8/22              0
# 2/9/22              0
# 2/10/22             0
# 2/11/22             0
# Length: 756, dtype: int64

# %%
print(f'There are {df.isna().sum().sum()} null values in our dataset but we consider all data. Null values doesn´t afect our research.')
# Out:
# There are 199 null values in our dataset but we consider all data. Null values doesn´t afect our research.

# %%
# Delete columns: Province/State, Lat, Long
df = df.drop(columns =['Province/State','Lat','Long'])
df
# Out:
#            Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  \
# 0             Afghanistan        0        0        0        0        0
# 1                 Albania        0        0        0        0        0
# 2                 Algeria        0        0        0        0        0
# 3                 Andorra        0        0        0        0        0
# 4                  Angola        0        0        0        0        0
# ..                    ...      ...      ...      ...      ...      ...
# 277    West Bank and Gaza        0        0        0        0        0
# 278  Winter Olympics 2022        0        0        0        0        0
# 279                 Yemen        0        0        0        0        0
# 280                Zambia        0        0        0        0        0
# 281              Zimbabwe        0        0        0        0        0
#
#      1/27/20  1/28/20  1/29/20  1/30/20  ...  2/2/22  2/3/22  2/4/22  2/5/22  \
# ...

# %%
grouped_df = df.groupby('Country/Region').sum()
grouped_df.to_excel('confirmed_cases_covid19.xlsx')
